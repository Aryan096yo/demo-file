# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan096yo/demo-file/blob/main/grad_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %%
y_pred = ((78.35*X) + 0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='green',label='b = 0')
plt.legend()
plt.show()

# %%
m = 78.35
b = 0

loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-209.27763408209216)

# %%
lr = 0.1

step_size = loss_slope*lr
step_size
# Out:
# np.float64(-20.927763408209216)

# %%
b = b - step_size
b
# Out:
# np.float64(20.927763408209216)

# %%
y_pred1 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='black',label='OLS')
plt.plot(X,y_pred,color='green',label='b = 0')
plt.plot(X,y_pred1,color='red',label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
#iteration 2
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-41.85552681641843)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-4.185552681641844)

# %%
b = b - step_size
b
# Out:
# np.float64(25.11331608985106)

# %%
y_pred2 = ((78.35 * X) + b).reshape(4)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='black',label='OLS')
plt.plot(X,y_pred2,color='red',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='green',label='b = {}'.format(b))
plt.plot(X,y_pred,color='blue',label='b = 0')
plt.legend()
plt.show()

# %%
# iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-8.371105363283675)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-0.8371105363283675)

# %%
b = b - step_size
b
# Out:
# np.float64(25.95042662617943)

# %%
y_pred3 = ((78.35 * X) + b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='black',label='OLS')
plt.plot(X,y_pred3,color='red',label='b = {}'.format(b))
plt.plot(X,y_pred2,color='green',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='blue',label='b = {}'.format(b))
plt.plot(X,y_pred,color='yellow',label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
b = -100
m = 78.35
lr = 0.01

epochs = 100

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*X.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m*X + b

  plt.plot(X,y_pred)
  plt.scatter(X,y)

# %%
### Part 2 - real implementation

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [89.45127625]
# 1.5241141768942867

# %%
m = 45.10

# %%
class GDRegressor:
   def __init__(self,learning_rate,epochs):
    self.m = 29.19
    self.b = -120
    self.lr = learning_rate
    self.epochs = epochs

   def fit(self,X,y):
      for i in range(self.epochs):
         loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
         self.b = self.b - (self.lr * loss_slope)
         print(loss_slope,self.b)
      print(self.b)

# %%
gd = GDRegressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# -25688.39570225116 -94.31160429774884
# -20550.71656180093 -73.7608877359479
# -16440.57324944074 -57.320314486507165
# -13152.45859955259 -44.16785588695458
# -10521.966879642077 -33.6458890073125
# -8417.573503713658 -25.22831550359884
# -6734.058802970928 -18.49425670062791
# -5387.247042376742 -13.107009658251169
# -4309.797633901394 -8.797212024349776
